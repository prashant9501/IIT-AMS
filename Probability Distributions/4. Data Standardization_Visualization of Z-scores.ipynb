# %%
import pandas as pd
df = pd.read_pickle("churn_prediction_v3.pkl")
df.head()
# Out:
#    vintage  age gender  dependents     occupation    city  \
# 0     2401   66   Male           0  self_employed     187
# 1     2648   35   Male           0  self_employed  100000
# 2     2494   31   Male           0       salaried     146
# 3     2629   90   Male           1  self_employed    1020
# 4     1879   42   Male           2  self_employed    1494
#
#   customer_nw_category branch_code  current_balance  \
# 0                    2         755          1458.71
# 1                    2        3214          5390.37
# 2                    2          41          3913.16
# 3                    2         582          2291.91
# 4                    3         388           927.72
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# 0                     1458.71                        1458.71
# 1                     8704.66                        7799.26
# 2                     5815.29                        4910.17
# 3                     2291.91                        2084.54
# 4                     1401.72                        1643.31
#
#    average_monthly_balance_prevQ2  current_month_credit  \
# 0                         1449.07                  0.20
# 1                        12419.41                  0.56
# 2                         2815.94                  0.61
# 3                         1006.54                  0.47
# 4                         1871.12                  0.33
#
#    previous_month_credit  current_month_debit  previous_month_debit  \
# 0                   0.20                 0.20                  0.20
# 1                   0.56              5486.27                100.56
# 2                   0.61              6046.73                259.23
# 3                   0.47                 0.47               2143.33
# 4                 714.61               588.62               1538.06
#
#    current_month_balance  previous_month_balance churn
# 0                1458.71                 1458.71   0.0
# 1                6496.78                 8787.61   0.0
# 2                5006.28                 5070.14   0.0
# 3                2291.91                 1669.79   1.0
# 4                1157.15                 1677.16   1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15929 entries, 0 to 15928
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   vintage                         15929 non-null  int64
#  1   age                             15929 non-null  int64
#  2   gender                          15929 non-null  category
#  3   dependents                      15929 non-null  int64
#  4   occupation                      15929 non-null  category
#  5   city                            15929 non-null  category
#  6   customer_nw_category            15929 non-null  category
#  7   branch_code                     15929 non-null  category
#  8   current_balance                 15929 non-null  float64
#  9   previous_month_end_balance      15929 non-null  float64
#  10  average_monthly_balance_prevQ   15929 non-null  float64
#  11  average_monthly_balance_prevQ2  15929 non-null  float64
#  12  current_month_credit            15929 non-null  float64
#  13  previous_month_credit           15929 non-null  float64
#  14  current_month_debit             15929 non-null  float64
#  15  previous_month_debit            15929 non-null  float64
#  16  current_month_balance           15929 non-null  float64
#  17  previous_month_balance          15929 non-null  float64
#  18  churn                           15929 non-null  category
# dtypes: category(6), float64(10), int64(3)
# memory usage: 1.7 MB

# %%
df.to_csv("temp_filename.csv", index=False)

# %%
df3 = pd.read_csv("temp_filename.csv")
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15929 entries, 0 to 15928
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   vintage                         15929 non-null  int64
#  1   age                             15929 non-null  int64
#  2   gender                          15929 non-null  object
#  3   dependents                      15929 non-null  int64
#  4   occupation                      15929 non-null  object
#  5   city                            15929 non-null  int64
#  6   customer_nw_category            15929 non-null  int64
#  7   branch_code                     15929 non-null  int64
#  8   current_balance                 15929 non-null  float64
#  9   previous_month_end_balance      15929 non-null  float64
#  10  average_monthly_balance_prevQ   15929 non-null  float64
#  11  average_monthly_balance_prevQ2  15929 non-null  float64
#  12  current_month_credit            15929 non-null  float64
#  13  previous_month_credit           15929 non-null  float64
#  14  current_month_debit             15929 non-null  float64
#  15  previous_month_debit            15929 non-null  float64
#  16  current_month_balance           15929 non-null  float64
#  17  previous_month_balance          15929 non-null  float64
#  18  churn                           15929 non-null  float64
# dtypes: float64(11), int64(6), object(2)
# memory usage: 2.3+ MB

# %%
df1 = pd.read_csv("temp_filename.csv")

# %%
path = r"C:\Users\Prashant\Downloads\AV\CBRE\Prashant\14-Oct-2023"
filename = r"\churn_prediction.csv"
df2 = pd.read_csv(path + filename)
df2.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     2401   66   Male         0.0  self_employed   187.0
# 1            2     2648   35   Male         0.0  self_employed     NaN
# 2            4     2494   31   Male         0.0       salaried   146.0
# 3            5     2629   90    NaN         NaN  self_employed  1020.0
# 4            6     1879   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  current_balance  ...  \
# 0                     2          755          1458.71  ...
# 1                     2         3214          5390.37  ...
# 2                     2           41          3913.16  ...
# 3                     2          582          2291.91  ...
# 4                     3          388           927.72  ...
#
#    average_monthly_balance_prevQ  average_monthly_balance_prevQ2  \
# 0                        1458.71                         1449.07
# 1                        7799.26                        12419.41
# 2                        4910.17                         2815.94
# 3                        2084.54                         1006.54
# 4                        1643.31                         1871.12
#
#    current_month_credit  previous_month_credit  current_month_debit  \
# 0                  0.20                   0.20                 0.20
# 1                  0.56                   0.56              5486.27
# 2                  0.61                   0.61              6046.73
# 3                  0.47                   0.47                 0.47
# 4                  0.33                 714.61               588.62
#
#    previous_month_debit  current_month_balance  previous_month_balance  \
# 0                  0.20                1458.71                 1458.71
# 1                100.56                6496.78                 8787.61
# 2                259.23                5006.28                 5070.14
# 3               2143.33                2291.91                 1669.79
# 4               1538.06                1157.15                 1677.16
#
#    last_transaction churn
# 0        2019-05-21   0.0
# 1        2019-11-01   0.0
# 2               NaT   0.0
# 3        2019-08-06   1.0
# 4        2019-11-03   1.0
#
# [5 rows x 21 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15930 entries, 0 to 15929
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   customer_id                     15930 non-null  int64
#  1   vintage                         15930 non-null  int64
#  2   age                             15930 non-null  int64
#  3   gender                          15642 non-null  object
#  4   dependents                      14582 non-null  float64
#  5   occupation                      15883 non-null  object
#  6   city                            15470 non-null  float64
#  7   customer_nw_category            15930 non-null  int64
#  8   branch_code                     15930 non-null  int64
#  9   current_balance                 15930 non-null  float64
#  10  previous_month_end_balance      15930 non-null  float64
#  11  average_monthly_balance_prevQ   15930 non-null  float64
#  12  average_monthly_balance_prevQ2  15930 non-null  float64
#  13  current_month_credit            15930 non-null  float64
#  14  previous_month_credit           15930 non-null  float64
#  15  current_month_debit             15930 non-null  float64
#  16  previous_month_debit            15929 non-null  float64
#  17  current_month_balance           15929 non-null  float64
#  18  previous_month_balance          15929 non-null  float64
#  19  last_transaction                15929 non-null  object
#  20  churn                           15929 non-null  float64
# dtypes: float64(13), int64(5), object(3)
# memory usage: 2.6+ MB

# %%
pwd  #print working directory
# Out:
# 'C:\\Users\\Prashant\\Downloads\\AV\\SBSA 2023\\Upto ML Basics\\Probability'

# %%
df.to_pickle("temp_pklfile.pkl")

# %% [markdown]
# $\alpha = \beta*\gamma_{\mu} - \Delta^\pi$

# %%
df['vintage'].min(), df['vintage'].max()
# Out:
# (438, 2776)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))

df['vintage'].plot.kde()  # kernel density estimation
plt.xlim([df['vintage'].min()-5, df['vintage'].max()+ 250])
ticks_pos = [df['vintage'].mean()-3*df['vintage'].std(), \
             df['vintage'].mean()-2*df['vintage'].std(), \
             df['vintage'].mean()-df['vintage'].std(), \
             df['vintage'].mean(), \
             df['vintage'].mean()+ df['vintage'].std(), \
            df['vintage'].mean() + 2*df['vintage'].std()]
             
             
plt.xticks(ticks_pos, labels=['$\mu-3\sigma$', '$\mu-2\sigma$', '$\mu-\sigma$', '$\mu$',  \
                              '$\mu+\sigma$', '$\mu+2\sigma$'], fontsize=15)

plt.axvline(df['vintage'].mean(), color='r', ls='-', lw=2)
plt.axvline(df['vintage'].mean()-df['vintage'].std(), color='g', ls='-', lw=2)
plt.axvline(df['vintage'].mean()+df['vintage'].std(), color='g', ls='-', lw=2)
plt.axvline(df['vintage'].mean()-2*df['vintage'].std(), color='y', ls='-', lw=2)
plt.axvline(df['vintage'].mean()-3*df['vintage'].std(), color='c', ls='-', lw=2)
plt.axvline(df['vintage'].mean()+ 2*df['vintage'].std(), color='k', ls='-', lw=2)

plt.axhline([0], color='k', ls='--', lw=2)

# %%
z_scores = (df['vintage'] - df['vintage'].mean() ) / df['vintage'].std()

# %%
z_scores.min()
# Out:
# -7.172529165391679

# %%
plt.figure(figsize=(10,6))

z_scores.plot.kde()
plt.xlim([z_scores.min()-1, z_scores.max()+1])
ticks_pos = [-3, -2, -1, 0, 1]
plt.xticks(ticks_pos)
# plt.xticks(ticks_pos, labels=['$\mu-3\sigma$', '$\mu-2\sigma$', '$\mu-\sigma$', '$\mu$',  '$\mu+\sigma$'], fontsize=15)

plt.axvline(0, color='r', ls='-', lw=2)
plt.axvline(-1, color='g', ls='-', lw=2)
plt.axvline(1, color='g', ls='-', lw=2)
plt.axvline(-2, color='y', ls='-', lw=2)
plt.axvline(-3, color='c', ls='-', lw=2)

plt.axhline([0], color='k', ls='--', lw=2)

# %%
import numpy as np

# %%
# A Statistics Exam Scores of students, out of 50
# Passign marks = 60% of the total =>> 30
scores = np.array([5, 12, 6, 15, 18, 22, 19, 28, 33, 38, 40, 26, 42])

# which means>> 5, 12, 6, 15, 18, 22, 19, 28, 26 >>> FAIL >>> 80% students Fail!!!

# %%
# Okay, All students whi score less than 1 std dev from the mean will fail !!!

# %%
scores_df = pd.DataFrame(scores, columns=['Scores'])
scores_df
# Out:
#     Scores
# 0        5
# 1       12
# 2        6
# 3       15
# 4       18
# 5       22
# 6       19
# 7       28
# 8       33
# 9       38
# 10      40
# 11      26
# 12      42

# %%
scores_df['Scores'].hist()
# Out:
# <Axes: >

# %%
scores_df['Z-scores'] = ( scores_df['Scores'] - scores_df['Scores'].mean() ) / scores_df['Scores'].std()
scores_df['Z-scores'] = np.round(scores_df['Z-scores'], 2)
scores_df
# Out:
#     Scores  Z-scores
# 0        5     -1.48
# 1       12     -0.92
# 2        6     -1.40
# 3       15     -0.68
# 4       18     -0.43
# 5       22     -0.11
# 6       19     -0.35
# 7       28      0.37
# 8       33      0.78
# 9       38      1.18
# 10      40      1.34
# 11      26      0.21
# 12      42      1.50

# %%
scores_df.describe()
# Out:
#           Scores   Z-scores
# count  13.000000  13.000000
# mean   23.384615   0.000769
# std    12.406574   1.000254
# min     5.000000  -1.480000
# 25%    15.000000  -0.680000
# 50%    22.000000  -0.110000
# 75%    33.000000   0.780000
# max    42.000000   1.500000

# %%
scores_df.sort_values(by = "Scores", ascending=True)
# Out:
#     Scores  Z-scores
# 0        5     -1.48
# 2        6     -1.40
# 1       12     -0.92
# 3       15     -0.68
# 4       18     -0.43
# 6       19     -0.35
# 5       22     -0.11
# 11      26      0.21
# 7       28      0.37
# 8       33      0.78
# 9       38      1.18
# 10      40      1.34
# 12      42      1.50
